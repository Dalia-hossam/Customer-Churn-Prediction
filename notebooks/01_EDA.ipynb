# %% [markdown]
# # Customer churn predection
# ## Exploratory Data Analysis
#
#
# ### Objectives
# - Understand the dataset
# - Analyze data types and quality
# - Clean the dataset
# - Perform Exploratory Data Analysis (EDA)
# - Discover bussiness insights related to customer churn

# %% [markdown]
# ## 1. **Imported Required Libraries**
#
# the following libraries are imported for data manipulation, visualization, and exploratory data analysis

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
from data_profiling import ProfileReport

# Display settings 
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

# plot settiings 
plt.rcParams["figure.figsize"]= (8,5)
sns.set_style("whitegrid")
from matplotlib_inline.backend_inline import set_matplotlib_formats
set_matplotlib_formats("png")

# %% [markdown]
# ## 2. **Load the Dataset**
#
# load the customer churn dataset into pandas dataframe

# %%
df = pd.read_csv("../data/raw_data/Customer-Churn.csv")

# %% [markdown]
# ## 3. **Dataset Preview**
#
# Display a few records to understand the dataset structure and features values

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges  \
# 0              Yes           Electronic check           29.85        29.85
# 1               No               Mailed check           56.95       1889.5
# 2              Yes               Mailed check           53.85       108.15
# 3               No  Bank transfer (automatic)           42.30      1840.75
# 4              Yes           Electronic check           70.70       151.65
#
#   Churn
# 0    No
# 1    No
# 2   Yes
# 3    No
# 4   Yes

# %%
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 7038          Yes               Yes             DSL            Yes
# 7039          Yes               Yes     Fiber optic             No
# 7040           No  No phone service             DSL            Yes
# 7041          Yes               Yes     Fiber optic             No
# 7042          Yes                No     Fiber optic            Yes
#
#      OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies  \
# 7038           No              Yes         Yes         Yes             Yes
# 7039          Yes              Yes          No         Yes             Yes
# 7040           No               No          No          No              No
# 7041           No               No          No          No              No
# 7042           No              Yes         Yes         Yes             Yes
#
#             Contract PaperlessBilling              PaymentMethod  \
# 7038        One year              Yes               Mailed check
# 7039        One year              Yes    Credit card (automatic)
# 7040  Month-to-month              Yes           Electronic check
# 7041  Month-to-month              Yes               Mailed check
# 7042        Two year              Yes  Bank transfer (automatic)
#
#       MonthlyCharges TotalCharges Churn
# 7038           84.80       1990.5    No
# 7039          103.20       7362.9    No
# 7040           29.60       346.45    No
# 7041           74.40        306.6   Yes
# 7042          105.65       6844.5    No

# %%
df.sample(10)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 798   3807-XHCJH  Female              0     Yes        Yes       1
# 1492  3254-YRILK    Male              1      No         No      19
# 6234  5995-LFTLE    Male              0      No         No      58
# 6360  8073-IJDCM  Female              0      No         No       1
# 5911  1976-AZZPJ    Male              0     Yes         No       7
# 2056  4138-NAXED    Male              0      No         No      51
# 2976  4830-FAXFM    Male              0      No        Yes      19
# 3506  2916-BQZLN    Male              0      No         No      19
# 3303  7786-WBJYI  Female              0      No         No       4
# 4933  9842-EFSYY  Female              0      No        Yes       4
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 798           Yes                No              No  No internet service
# 1492          Yes               Yes     Fiber optic                   No
# 6234          Yes               Yes              No  No internet service
# 6360          Yes                No              No  No internet service
# 5911           No  No phone service             DSL                  Yes
# 2056          Yes               Yes     Fiber optic                   No
# 2976          Yes               Yes              No  No internet service
# 3506          Yes               Yes     Fiber optic                  Yes
# 3303          Yes               Yes     Fiber optic                   No
# 4933           No  No phone service             DSL                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 798   No internet service  No internet service  No internet service
# 1492                  Yes                   No                   No
# 6234  No internet service  No internet service  No internet service
# 6360  No internet service  No internet service  No internet service
# 5911                  Yes                   No                   No
# 2056                  Yes                   No                   No
# 2976  No internet service  No internet service  No internet service
# 3506                   No                  Yes                   No
# 3303                  Yes                   No                   No
# 4933                  Yes                  Yes                   No
#
#               StreamingTV      StreamingMovies        Contract  \
# 798   No internet service  No internet service  Month-to-month
# 1492                  Yes                   No  Month-to-month
# 6234  No internet service  No internet service        Two year
# 6360  No internet service  No internet service  Month-to-month
# 5911                   No                   No  Month-to-month
# 2056                   No                   No  Month-to-month
# 2976  No internet service  No internet service  Month-to-month
# 3506                   No                   No  Month-to-month
# 3303                   No                   No  Month-to-month
# 4933                  Yes                  Yes  Month-to-month
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges  \
# 798                No           Electronic check           20.00           20
# 1492              Yes           Electronic check           88.20       1775.8
# 6234              Yes    Credit card (automatic)           25.30      1474.35
# 6360              Yes               Mailed check           20.30         20.3
# 5911               No               Mailed check           34.20        256.6
# 2056               No  Bank transfer (automatic)           81.00      4085.75
# 2976              Yes    Credit card (automatic)           24.10        439.2
# 3506              Yes           Electronic check           84.75      1651.95
# 3303               No  Bank transfer (automatic)           77.95       305.55
# 4933              Yes               Mailed check           57.20       223.75
#
#      Churn
# 798     No
# 1492   Yes
# 6234    No
# 6360   Yes
# 5911    No
# 2056    No
# 2976    No
# 3506    No
# 3303   Yes
# 4933    No

# %% [markdown]
# ## 4. **Dataset Overview**
#
# This section provides general information about the dataset, including the number of records, number of features (columns), data types, and descriptive statistics

# %%
print("Number of Rows:" ,df.shape[0])
print("Number of cloumns:", df.shape[1])
# Out:
# Number of Rows: 7043
# Number of cloumns: 21

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.describe(include= object)
# Out:
#         customerID gender Partner Dependents PhoneService MultipleLines  \
# count         7043   7043    7043       7043         7043          7043
# unique        7043      2       2          2            2             3
# top     7590-VHVEG   Male      No         No          Yes            No
# freq             1   3555    3641       4933         6361          3390
#
#        InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# count             7043           7043         7043             7043
# unique               3              3            3                3
# top        Fiber optic             No           No               No
# freq              3096           3498         3088             3095
#
#        TechSupport StreamingTV StreamingMovies        Contract  \
# count         7043        7043            7043            7043
# unique           3           3               3               3
# top             No          No              No  Month-to-month
# freq          3473        2810            2785            3875
#
#        PaperlessBilling     PaymentMethod TotalCharges Churn
# count              7043              7043         7043  7043
# unique                2                 4         6531     2
# top                 Yes  Electronic check         20.2    No
# freq               4171              2365           11  5174

# %% [markdown]
# ### Initial Observation
#
# - The dataset contains **7043 customer records**
# - It includes**21 features**
# - Most features are categorical
# - The `TotalCharges` column is sorted as object (string) and requires further inspection

# %% [markdown]
# ## 5.**Data Quality Assessment**
#
# Before performing any analysis, the dataset is examined for missing values, duplicate records, incorrect data types, and inconsistent values

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
(df.isnull().sum() / len(df))*100
# Out:
# customerID          0.0
# gender              0.0
# SeniorCitizen       0.0
# Partner             0.0
# Dependents          0.0
# tenure              0.0
# PhoneService        0.0
# MultipleLines       0.0
# InternetService     0.0
# OnlineSecurity      0.0
# OnlineBackup        0.0
# DeviceProtection    0.0
# TechSupport         0.0
# StreamingTV         0.0
# StreamingMovies     0.0
# Contract            0.0
# PaperlessBilling    0.0
# PaymentMethod       0.0
# MonthlyCharges      0.0
# TotalCharges        0.0
# Churn               0.0
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique().sort_values()
# Out:
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# PhoneService           2
# PaperlessBilling       2
# Churn                  2
# MultipleLines          3
# TechSupport            3
# StreamingTV            3
# OnlineBackup           3
# DeviceProtection       3
# StreamingMovies        3
# Contract               3
# OnlineSecurity         3
# InternetService        3
# PaymentMethod          4
# tenure                73
# MonthlyCharges      1585
# TotalCharges        6531
# customerID          7043
# dtype: int64

# %%
# count blank or whitespace-only values in object columns
for col in df.select_dtypes(include=["object", "string"]).columns:
    blanks= df[col].astype(str).str.strip().eq("").sum()
    if blanks > 0:
        print(f"{col}:{blanks}" )
# Out:
# TotalCharges:11

# %%
blank_total_charges = df[df['TotalCharges'].astype(str).str.strip() ==""]
blank_total_charges
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 488            No  No phone service             DSL                  Yes
# 753           Yes                No              No  No internet service
# 936           Yes                No             DSL                  Yes
# 1082          Yes               Yes              No  No internet service
# 1340           No  No phone service             DSL                  Yes
# 3331          Yes                No              No  No internet service
# 3826          Yes               Yes              No  No internet service
# 4380          Yes                No              No  No internet service
# 5218          Yes                No              No  No internet service
# 6670          Yes               Yes             DSL                   No
# 6754          Yes               Yes             DSL                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 488                    No                  Yes                  Yes
# 753   No internet service  No internet service  No internet service
# 936                   Yes                  Yes                   No
# 1082  No internet service  No internet service  No internet service
# 1340                  Yes                  Yes                  Yes
# 3331  No internet service  No internet service  No internet service
# 3826  No internet service  No internet service  No internet service
# 4380  No internet service  No internet service  No internet service
# 5218  No internet service  No internet service  No internet service
# 6670                  Yes                  Yes                  Yes
# 6754                  Yes                   No                  Yes
#
#               StreamingTV      StreamingMovies  Contract PaperlessBilling  \
# 488                   Yes                   No  Two year              Yes
# 753   No internet service  No internet service  Two year               No
# 936                   Yes                  Yes  Two year               No
# 1082  No internet service  No internet service  Two year               No
# 1340                  Yes                   No  Two year               No
# 3331  No internet service  No internet service  Two year               No
# 3826  No internet service  No internet service  Two year               No
# 4380  No internet service  No internet service  Two year               No
# 5218  No internet service  No internet service  One year              Yes
# 6670                  Yes                   No  Two year               No
# 6754                   No                   No  Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 488   Bank transfer (automatic)           52.55                 No
# 753                Mailed check           20.25                 No
# 936                Mailed check           80.85                 No
# 1082               Mailed check           25.75                 No
# 1340    Credit card (automatic)           56.05                 No
# 3331               Mailed check           19.85                 No
# 3826               Mailed check           25.35                 No
# 4380               Mailed check           20.00                 No
# 5218               Mailed check           19.70                 No
# 6670               Mailed check           73.35                 No
# 6754  Bank transfer (automatic)           61.90                 No

# %% [markdown]
# ### Hidden Missing values
#
# - Although no explicity missing values were detected, an additionl inspection was performed to identify hidden missing values represented in blank spaces, The analysis revealed that the `TotalCharges`columns contains blank entries, which prevented it from being recognized as numeric features

# %% [markdown]
# ## 6.**Data Cleaning**
#
# The purpose of this step is to improve the overall quality of the dataset before performing EDA. Based on the previous assesssment. the dataset is generally clean, with no dublicate records or explcit missing values. However, a hidden data quality issue was identified in the `TotalCharges` column, which requires correction.

# %%
df['TotalCharges'] == df['TotalCharges'].replace(r'^\s*$', np.nan, regex= True)
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors= "coerce")

# %%
df['TotalCharges'].isnull().sum()
# Out:
# np.int64(11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7032 non-null   float64
#  20  Churn             7043 non-null   object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.1+ MB

# %% [markdown]
# > handle this missing values wil be done later at the preprocessing to avoid data leakage

# %% [markdown]
# ### Inspect Categorical Features
#
# Categorical variables were reviewded to identify inconsitent labels, unexpected categories, or hidden blanks.

# %%
categorical_columns = df.select_dtypes(include=["object", "string"]).columns
categorical_columns_selected = categorical_columns.drop("customerID")
for col in categorical_columns_selected:
   display(
       pd.DataFrame({
           "Category": df[col].value_counts(dropna= False).index, 
           "Count": df[col].value_counts(dropna= False).values
       }).rename_axis(None, axis= 1).style.set_caption(f"{col} Distribution")
   )
# Out:
# <style type="text/css">
# </style>
# <table id="T_9ebc1">
#   <caption>gender Distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ebc1_level0_col0" class="col_heading level0 col0" >Category</th>
#       <th id="T_9ebc1_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ebc1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9ebc1_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_9ebc1_row0_col1" class="data row0 col1" >3555</td>
#     </tr>
#     <tr>
#       <th id="T_9ebc1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9ebc1_row1_col0" class="data row1 col0" >Female</td>
#       <td id="T_9ebc1_row1_col1" class="data row1 col1" >3488</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_fc1eb">
#   <caption>Partner Distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc1eb_level0_col0" class="col_heading level0 col0" >Category</th>
#       <th id="T_fc1eb_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc1eb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fc1eb_row0_col0" class="data row0 col0" >No</td>
#       <td id="T_fc1eb_row0_col1" class="data row0 col1" >3641</td>
#     </tr>
#     <tr>
#       <th id="T_fc1eb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fc1eb_row1_col0" class="data row1 col0" >Yes</td>
#       <td id="T_fc1eb_row1_col1" class="data row1 col1" >3402</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_ad015">
#   <caption>Dependents Distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ad015_level0_col0" class="col_heading level0 col0" >Category</th>
#       <th id="T_ad015_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad015_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ad015_row0_col0" class="data row0 col0" >No</td>
#       <td id="T_ad015_row0_col1" class="data row0 col1" >4933</td>
#     </tr>
#     <tr>
#       <th id="T_ad015_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ad015_row1_col0" class="data row1 col0" >Yes</td>
#       <td id="T_ad015_row1_col1" class="data row1 col1" >2110</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_b093f">
#   <caption>PhoneService Distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b093f_level0_col0" class="col_heading level0 col0" >Category</th>
#       <th id="T_b093f_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b093f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b093f_row0_col0" class="data row0 col0" >Yes</td>
#       <td id="T_b093f_row0_col1" class="data row0 col1" >6361</td>
#     </tr>
#     <tr>
#       <th id="T_b093f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b093f_row1_col0" class="data row1 col0" >No</td>
#       <td id="T_b093f_row1_col1" class="data row1 col1" >682</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_604d7">
#   <caption>MultipleLines Distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_604d7_level0_col0" class="col_heading level0 col0" >Category</th>
#       <th id="T_604d7_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_604d7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_604d7_row0_col0" class="data row0 col0" >No</td>
#       <td id="T_604d7_row0_col1" class="data row0 col1" >3390</td>
#     </tr>
#     <tr>
#       <th id="T_604d7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_604d7_row1_col0" class="data row1 col0" >Yes</td>
#       <td id="T_604d7_row1_col1" class="data row1 col1" >2971</td>
#     </tr>
#     <tr>
#       <th id="T_604d7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_604d7_row2_col0" class="data row2 col0" >No phone service</td>
#       <td id="T_604d7_row2_col1" class="data row2 col1" >682</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_45f34">
#   <caption>InternetService Distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45f34_level0_col0" class="col_heading level0 col0" >Category</th>
#       <th id="T_45f34_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45f34_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_45f34_row0_col0" class="data row0 col0" >Fiber optic</td>
#       <td id="T_45f34_row0_col1" class="data row0 col1" >3096</td>
#     </tr>
#     <tr>
#       <th id="T_45f34_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_45f34_row1_col0" class="data row1 col0" >DSL</td>
#       <td id="T_45f34_row1_col1" class="data row1 col1" >2421</td>
#     </tr>
#     <tr>
#       <th id="T_45f34_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_45f34_row2_col0" class="data row2 col0" >No</td>
#       <td id="T_45f34_row2_col1" class="data row2 col1" >1526</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_8dc4f">
#   <caption>OnlineSecurity Distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8dc4f_level0_col0" class="col_heading level0 col0" >Category</th>
#       <th id="T_8dc4f_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8dc4f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8dc4f_row0_col0" class="data row0 col0" >No</td>
#       <td id="T_8dc4f_row0_col1" class="data row0 col1" >3498</td>
#     </tr>
#     <tr>
#       <th id="T_8dc4f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8dc4f_row1_col0" class="data row1 col0" >Yes</td>
#       <td id="T_8dc4f_row1_col1" class="data row1 col1" >2019</td>
#     </tr>
#     <tr>
#       <th id="T_8dc4f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8dc4f_row2_col0" class="data row2 col0" >No internet service</td>
#       <td id="T_8dc4f_row2_col1" class="data row2 col1" >1526</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_a6346">
#   <caption>OnlineBackup Distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6346_level0_col0" class="col_heading level0 col0" >Category</th>
#       <th id="T_a6346_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6346_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a6346_row0_col0" class="data row0 col0" >No</td>
#       <td id="T_a6346_row0_col1" class="data row0 col1" >3088</td>
#     </tr>
#     <tr>
#       <th id="T_a6346_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a6346_row1_col0" class="data row1 col0" >Yes</td>
#       <td id="T_a6346_row1_col1" class="data row1 col1" >2429</td>
#     </tr>
#     <tr>
#       <th id="T_a6346_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a6346_row2_col0" class="data row2 col0" >No internet service</td>
#       <td id="T_a6346_row2_col1" class="data row2 col1" >1526</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_36f32">
#   <caption>DeviceProtection Distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_36f32_level0_col0" class="col_heading level0 col0" >Category</th>
#       <th id="T_36f32_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_36f32_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_36f32_row0_col0" class="data row0 col0" >No</td>
#       <td id="T_36f32_row0_col1" class="data row0 col1" >3095</td>
#     </tr>
#     <tr>
#       <th id="T_36f32_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_36f32_row1_col0" class="data row1 col0" >Yes</td>
#       <td id="T_36f32_row1_col1" class="data row1 col1" >2422</td>
#     </tr>
#     <tr>
#       <th id="T_36f32_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_36f32_row2_col0" class="data row2 col0" >No internet service</td>
#       <td id="T_36f32_row2_col1" class="data row2 col1" >1526</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_cbdc5">
#   <caption>TechSupport Distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cbdc5_level0_col0" class="col_heading level0 col0" >Category</th>
#       <th id="T_cbdc5_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cbdc5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cbdc5_row0_col0" class="data row0 col0" >No</td>
#       <td id="T_cbdc5_row0_col1" class="data row0 col1" >3473</td>
#     </tr>
#     <tr>
#       <th id="T_cbdc5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cbdc5_row1_col0" class="data row1 col0" >Yes</td>
#       <td id="T_cbdc5_row1_col1" class="data row1 col1" >2044</td>
#     </tr>
#     <tr>
#       <th id="T_cbdc5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cbdc5_row2_col0" class="data row2 col0" >No internet service</td>
#       <td id="T_cbdc5_row2_col1" class="data row2 col1" >1526</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_68f72">
#   <caption>StreamingTV Distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_68f72_level0_col0" class="col_heading level0 col0" >Category</th>
#       <th id="T_68f72_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68f72_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_68f72_row0_col0" class="data row0 col0" >No</td>
#       <td id="T_68f72_row0_col1" class="data row0 col1" >2810</td>
#     </tr>
#     <tr>
#       <th id="T_68f72_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_68f72_row1_col0" class="data row1 col0" >Yes</td>
#       <td id="T_68f72_row1_col1" class="data row1 col1" >2707</td>
#     </tr>
#     <tr>
#       <th id="T_68f72_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_68f72_row2_col0" class="data row2 col0" >No internet service</td>
#       <td id="T_68f72_row2_col1" class="data row2 col1" >1526</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_f6014">
#   <caption>StreamingMovies Distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f6014_level0_col0" class="col_heading level0 col0" >Category</th>
#       <th id="T_f6014_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f6014_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f6014_row0_col0" class="data row0 col0" >No</td>
#       <td id="T_f6014_row0_col1" class="data row0 col1" >2785</td>
#     </tr>
#     <tr>
#       <th id="T_f6014_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f6014_row1_col0" class="data row1 col0" >Yes</td>
#       <td id="T_f6014_row1_col1" class="data row1 col1" >2732</td>
#     </tr>
#     <tr>
#       <th id="T_f6014_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f6014_row2_col0" class="data row2 col0" >No internet service</td>
#       <td id="T_f6014_row2_col1" class="data row2 col1" >1526</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_c653d">
#   <caption>Contract Distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c653d_level0_col0" class="col_heading level0 col0" >Category</th>
#       <th id="T_c653d_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c653d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c653d_row0_col0" class="data row0 col0" >Month-to-month</td>
#       <td id="T_c653d_row0_col1" class="data row0 col1" >3875</td>
#     </tr>
#     <tr>
#       <th id="T_c653d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c653d_row1_col0" class="data row1 col0" >Two year</td>
#       <td id="T_c653d_row1_col1" class="data row1 col1" >1695</td>
#     </tr>
#     <tr>
#       <th id="T_c653d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c653d_row2_col0" class="data row2 col0" >One year</td>
#       <td id="T_c653d_row2_col1" class="data row2 col1" >1473</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_39fb4">
#   <caption>PaperlessBilling Distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_39fb4_level0_col0" class="col_heading level0 col0" >Category</th>
#       <th id="T_39fb4_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39fb4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_39fb4_row0_col0" class="data row0 col0" >Yes</td>
#       <td id="T_39fb4_row0_col1" class="data row0 col1" >4171</td>
#     </tr>
#     <tr>
#       <th id="T_39fb4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_39fb4_row1_col0" class="data row1 col0" >No</td>
#       <td id="T_39fb4_row1_col1" class="data row1 col1" >2872</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_2e9b7">
#   <caption>PaymentMethod Distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e9b7_level0_col0" class="col_heading level0 col0" >Category</th>
#       <th id="T_2e9b7_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e9b7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2e9b7_row0_col0" class="data row0 col0" >Electronic check</td>
#       <td id="T_2e9b7_row0_col1" class="data row0 col1" >2365</td>
#     </tr>
#     <tr>
#       <th id="T_2e9b7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2e9b7_row1_col0" class="data row1 col0" >Mailed check</td>
#       <td id="T_2e9b7_row1_col1" class="data row1 col1" >1612</td>
#     </tr>
#     <tr>
#       <th id="T_2e9b7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2e9b7_row2_col0" class="data row2 col0" >Bank transfer (automatic)</td>
#       <td id="T_2e9b7_row2_col1" class="data row2 col1" >1544</td>
#     </tr>
#     <tr>
#       <th id="T_2e9b7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2e9b7_row3_col0" class="data row3 col0" >Credit card (automatic)</td>
#       <td id="T_2e9b7_row3_col1" class="data row3 col1" >1522</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_50bb3">
#   <caption>Churn Distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50bb3_level0_col0" class="col_heading level0 col0" >Category</th>
#       <th id="T_50bb3_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50bb3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_50bb3_row0_col0" class="data row0 col0" >No</td>
#       <td id="T_50bb3_row0_col1" class="data row0 col1" >5174</td>
#     </tr>
#     <tr>
#       <th id="T_50bb3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_50bb3_row1_col0" class="data row1 col0" >Yes</td>
#       <td id="T_50bb3_row1_col1" class="data row1 col1" >1869</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Saving processed csv

# %%
df.to_csv("../data/processed_data/processed_customer_churn.csv", index= False)

# %% [markdown]
# ### Cleaning Summary
#
# - identified hidden missing values in `TotalCharges`
#
# - converted blank entries to `NAN`.
#
# - changed `TotalCharges` to numeric data type
#
# - verfied the consistency of categorical features
#
# - prepered the data set for the EDA
#
# - saved the processed dataset for the next project phase

# %% [markdown]
# ## 7. **Exploratory Data Analysis (EDA)**
#
# > The purpose of this section is explore the dataset using statistical summaries and visualizations to better understand customer characteristics and identify factors that may influence customer churn

# %% [markdown]
# ### **Automated Data Profiling**
#
# An automated data profiling report was generated using **YData Profiling** to provide a comprehensive overview of the dataset, including feature distributions, missing values, correlations, and potential data quality issues. The report complements the manual exploratory data analysis presented in this notebook.

# %%
profile = ProfileReport(
    df,
    title="Customer Churn Data Profiling Report",
    explorative=True
)

# %%
profile.to_notebook_iframe()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 21/21 [00:00<00:00, 46.71it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling v4.19.1&quot; name=generator&gt;&lt;meta content=https://github.com/Data-Centric-AI-Community/data-profiling name=url&gt;&lt;meta content=&quot;2026-07-30 07:29:10.832220&quot; name=date&gt;&lt;title&gt;Customer Churn Data Profiling Report&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
#  */:root,[data-bs-theme=light]{--bs-blue:#0d6efd;--bs-indigo:#6610f2;--bs-purple:#6f42c1;--bs-pink:#d63384;--bs-red:#dc3545;--bs-orange:#fd7e14;--bs-yellow:#ffc107;--bs-green:#198754;--bs-teal:#20c997;--bs-cyan:#0dcaf0;--bs-black:#000;--bs-white:#fff;--bs-gray:#6c757d;--bs-gray-dark:#343a40;--bs-gray-100:#f8f9fa;--bs-gray-200:#e9ecef;--bs-gray-300:#dee2e6;--bs-gray-400:#ced4da;--bs-gray-500:#adb5bd;--bs-gray-600:#6c757d;--bs-gray-700:#495057;--bs-gray-800:#343a40;--bs-gray-900:#212529;--bs-primary:#0d6efd;--bs-secondary:#6c757d;--bs-success:#198754;--bs-info:#0dcaf0;--bs-warning:#ffc107;--bs-danger:#dc3545;--bs-light:#f8f9fa;--bs-dark:#212529;--bs-primary-rgb:13,110,253;--bs-secondary-rgb:108,117,125;--bs-success-rgb:25,135,84;--bs-info-rgb:13,202,240;--bs-warning-rgb:255,193,7;--bs-danger-rgb:220,53,69;--bs-light-rgb:248,249,250;--bs-dark-rgb:33,37,41;--bs-primary-text-emphasis:#052c65;--bs-secondary-text-emphasis:#2b2f32;--bs-success-text-emphasis:#0a3622;--bs-info-text-emphasis:#055160;--bs-warning-text-emphasis:#664d03;--bs-danger-text-emphasis:#58151c;--bs-light-text-emphasis:#495057;--bs-dark-text-emphasis:#495057;--bs-primary-bg-subtle:#cfe2ff;--bs-secondary-bg-subtle:#e2e3e5;--bs-success-bg-subtle:#d1e7dd;--bs-info-bg-subtle:#cff4fc;--bs-warning-bg-subtle:#fff3cd;--bs-danger-bg-subtle:#f8d7da;--bs-light-bg-subtle:#fcfcfd;--bs-dark-bg-subtle:#ced4da;--bs-primary-border-subtle:#9ec5fe;--bs-secondary-border-subtle:#c4c8cb;--bs-success-border-subtle:#a3cfbb;--bs-info-border-subtle:#9eeaf9;--bs-warning-border-subtle:#ffe69c;--bs-danger-border-subtle:#f1aeb5;--bs-light-border-subtle:#e9ecef;--bs-dark-border-subtle:#adb5bd;--bs-white-rgb:255,255,255;--bs-black-rgb:0,0,0;--bs-font-sans-serif:system-ui,-apple-system,&quot;Segoe UI&quot;,Roboto,&quot;Helvetica Neue&quot;,&quot;Noto Sans&quot;,&quot;Liberation Sans&quot;,Arial,sans-serif,&quot;Apple Color Emoji&quot;,&quot;Segoe UI Emoji&quot;,&quot;Segoe UI Symbol&quot;,&quot;Noto Color Emoji&quot;;--bs-font-monospace:SFMono-Regular,Menlo,Monaco,Consolas,&quot;Liberation Mono&quot;,&quot;Courier New&quot;,monospace;--bs-gradient:linear-gradient(180deg, rgba(255, 255, 255, 0.15), rgba(255, 255, 255, 0));--bs-body-font-family:var(--bs-font-sans-serif);--bs-body-font-size:1rem;--bs-body-font-weight:400;--bs-body-line-height:1.5;--bs-body-color:#212529;--bs-body-color-rgb:33,37,41;--bs-body-bg:#fff;--bs-body-bg-rgb:255,255,255;--bs-emphasis-color:#000;--bs-emphasis-color-rgb:0,0,0;--bs-secondary-color:rgba(33, 37, 41, 0.75);--bs-secondary-color-rgb:33,37,41;--bs-secondary-bg:#e9ecef;--bs-secondary-bg-rgb:233,236,239;--bs-tertiary-color:rgba(33, 37, 41, 0.5);--bs-tertiary-color-rgb:33,37,41;--bs-tertiary-bg:#f8f9fa;--bs-tertiary-bg-rgb:248,249,250;--bs-heading-color:inherit;--bs-link-color:#0d6efd;--bs-link-color-rgb:13,110,253;--bs-link-decoration:underline;--bs-link-hover-color:#0a58ca;--bs-link-hover-color-rgb:10,88,202;--bs-code-color:#d63384;--bs-highlight-color:#212529;--bs-highlight-bg:#fff3cd;--bs-border-width:1px;--bs-border-style:solid;--bs-border-color:#dee2e6;--bs-border-color-translucent:rgba(0, 0, 0, 0.175);--bs-border-radius:0.375rem;--bs-border-radius-sm:0.25rem;--bs-border-radius-lg:0.5rem;--bs-border-radius-xl:1rem;--bs-border-radius-xxl:2rem;--bs-border-radius-2xl:var(--bs-border-radius-xxl);--bs-border-radius-pill:50rem;--bs-box-shadow:0 0.5rem 1rem rgba(0, 0, 0, 0.15);--bs-box-shadow-sm:0 0.125rem 0.25rem rgba(0, 0, 0, 0.075);--bs-box-shadow-lg:0 1rem 3rem rgba(0, 0, 0, 0.175);--bs-box-shadow-inset:inset 0 1px 2px rgba(0, 0, 0, 0.075);--bs-focus-ring-width:0.25rem;--bs-focus-ring-opacity:0.25;--bs-focus-ring-color:rgba(13, 110, 253, 0.25);--bs-form-valid-color:#198754;--bs-form-valid-border-color:#198754;--bs-form-invalid-color:#dc3545;--bs-form-invalid-border-color:#dc3545}[data-bs-theme=dark]{color-scheme:dark;--bs-body-color:#dee2e6;--bs-body-color-rgb:222,226,230;--bs-body-bg:#212529;--bs-body-bg-rgb:33,37,41;--bs-emphasis-color:#fff;--bs-emphasis-color-rgb:2 ...

# %% [markdown]
# ### **Manual EDA**

# %% [markdown]
# ### 1. Churn distribution
#  Before analyzing the features, it is important to examine the distribution of the target variable (`Churn`) too understand the balane bettween customers who stayed and those who left

# %%
df['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df['Churn'].value_counts(normalize= True)*100
# Out:
# Churn
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %%
plt.figure()
sns.countplot(data= df, x = "Churn")
plt.title("Customer Churn Distribution")
plt.xlabel("Churn")
plt.ylabel("Number of Customers")
plt.show()

# %% [markdown]
# ### Observation
#  The target variable is moderately imbalanced. Approximately **73,45%** of customers did not churn, while **26,54** left the company. This indicates that most customers were retained, but the class imbalane should be considered during the model development and evaluation stage.

# %% [markdown]
# ### Numerical Features Analysis
#
# The Numerical variables are analyzed to understand their distributions, detect potential outliers, and identifyy patterns that may be assosisted with customers churn

# %%
numerical_cols = ["tenure", "MonthlyCharges", "TotalCharges"]

df[numerical_cols].describe().T
# Out:
#                  count         mean          std    min     25%       50%  \
# tenure          7043.0    32.371149    24.559481   0.00    9.00    29.000
# MonthlyCharges  7043.0    64.761692    30.090047  18.25   35.50    70.350
# TotalCharges    7032.0  2283.300441  2266.771362  18.80  401.45  1397.475
#
#                       75%      max
# tenure            55.0000    72.00
# MonthlyCharges    89.8500   118.75
# TotalCharges    3794.7375  8684.80

# %%
for col in numerical_cols:
    plt.figure()
    sns.histplot(df[col], bins= 30, kde= True)
    plt.title(f"Distribution of{col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %% [markdown]
# ### 2. Distribution Analysis
#
# The distribution of numerical features are visualized to identify skewness, concentration of values, and over all data patterns.

# %% [markdown]
# ### 3. Outlier Detection
#
# Boxplots are used to identify potential outliers in the numerical variables.

# %%
for col in numerical_cols: 
    plt.figure()
    sns.boxenplot(x=df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %% [markdown]
# ### Observation
#  The boxplots do not reveal significant outliers in the numerial features. While `MonthlyCharges` and `TotalCharges` show slightly wider distribution, the observeed values appear to be valid customer records rather than data quality issues, therefore, no outlier treatment is required at this stage

# %% [markdown]
# ### 4. Relationship with Churn

# %% [markdown]
# - Tenure vs Churn
#
# > The relationship between customer tenure and churn is examined to determine whether customers with shorter or longer subscription are more likely to leave

# %%
plt.figure()
sns.boxenplot(data= df, x = "Churn", y = "tenure")
plt.title("Tenure by Churn")
# Out:
# Text(0.5, 1.0, 'Tenure by Churn')

# %% [markdown]
# - Customers who churned generally have shorter tenures than those who remained. In contrast,  Customers with longer supscription periods are more likely to stay with the company, suggesting that customerrs loyalty increases over time

# %% [markdown]
# - Monthly charges vs Churn
#
# > This visualization exoplores whethr customers with higher monthly charges are more likely to churn

# %%
plt.figure()
sns.boxenplot(data = df, x = "Churn", y = "MonthlyCharges")
plt.title("Monthly Charges by Churn")
plt.show()

# %% [markdown]
# - Customers who churned tend to have higher monthly charges compared to those who stayed. This suggests that higher monthly costs may be associated with an increased likelihood of customer churn

# %% [markdown]
# - Total Charges vs Churn
#
# > This analysis investigation the relationship between customers' total spending and churn behavior

# %%
plt.figure()
sns.boxenplot(data = df, x = "Churn", y = "TotalCharges")
plt.title("Total Chrges by Churn")
plt.show()

# %% [markdown]
# - Customers who stayed with the company generally have higher total charges than customers who churned. THis is expected becuse long-term customers accumulate higher total payments over time

# %% [markdown]
# ## **7. Categorical Features Analysis**

# %% [markdown]
# ### Categorical Feature vs churn
#
# This section explores the relationship between categorical features and customer churn to identify customer characterstics associated with a higher likelihood of leaving the company

# %%
categorical_features = df.select_dtypes(include=['object', 'string']).columns.tolist()
# Exclude identifier and target 

categorical_features.remove("customerID")
categorical_features.remove("Churn")
categorical_features
# Out:
# ['gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod']

# %%
for col in categorical_features:
    print(col)

    churn_rate = (
        pd.crosstab(df[col], df["Churn"], normalize="index") * 100
    ).round(2)

    display(churn_rate)
# Out:
# gender
# Churn      No    Yes
# gender
# Female  73.08  26.92
# Male    73.84  26.16
# Partner
# Churn       No    Yes
# Partner
# No       67.04  32.96
# Yes      80.34  19.66
# Dependents
# Churn          No    Yes
# Dependents
# No          68.72  31.28
# Yes         84.55  15.45
# PhoneService
# Churn            No    Yes
# PhoneService
# No            75.07  24.93
# Yes           73.29  26.71
# MultipleLines
# Churn                No    Yes
# MultipleLines
# No                74.96  25.04
# No phone service  75.07  24.93
# Yes               71.39  28.61
# InternetService
# Churn               No    Yes
# InternetService
# DSL              81.04  18.96
# Fiber optic      58.11  41.89
# No               92.60   7.40
# OnlineSecurity
# Churn                   No    Yes
# OnlineSecurity
# No                   58.23  41.77
# No internet service  92.60   7.40
# Yes                  85.39  14.61
# OnlineBackup
# Churn                   No    Yes
# OnlineBackup
# No                   60.07  39.93
# No internet service  92.60   7.40
# Yes                  78.47  21.53
# DeviceProtection
# Churn                   No    Yes
# DeviceProtection
# No                   60.87  39.13
# No internet service  92.60   7.40
# Yes                  77.50  22.50
# TechSupport
# Churn                   No    Yes
# TechSupport
# No                   58.36  41.64
# No internet service  92.60   7.40
# Yes                  84.83  15.17
# StreamingTV
# Churn                   No    Yes
# StreamingTV
# No                   66.48  33.52
# No internet service  92.60   7.40
# Yes                  69.93  30.07
# StreamingMovies
# Churn                   No    Yes
# StreamingMovies
# No                   66.32  33.68
# No internet service  92.60   7.40
# Yes                  70.06  29.94
# Contract
# Churn              No    Yes
# Contract
# Month-to-month  57.29  42.71
# One year        88.73  11.27
# Two year        97.17   2.83
# PaperlessBilling
# Churn                No    Yes
# PaperlessBilling
# No                83.67  16.33
# Yes               66.43  33.57
# PaymentMethod
# Churn                         No    Yes
# PaymentMethod
# Bank transfer (automatic)  83.29  16.71
# Credit card (automatic)    84.76  15.24
# Electronic check           54.71  45.29
# Mailed check               80.89  19.11

# %%
for col in categorical_features:
    churn_rate =( pd.crosstab(df[col],df["Churn"],normalize= "index")*100)
    churn_rate.plot(kind="bar", figsize=(7,8))
    plt.title(f"Churn Rate by {col}")
    plt.ylabel("Precentage")
    plt.xticks(rotation = 20)
    plt.legend(title= "Churn")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## **Correlation Analysis**
#
# This section examines the relationships among numerical features using a correlation Matrix

# %%
plt.figure(figsize=(6, 5))

corr = df[numerical_cols].corr()

sns.heatmap(
    corr,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    linewidths=0.5,
    square=True,
    cbar_kws={"shrink": 0.8}
)

plt.title("Correlation Matrix of Numerical Features", fontsize=14, pad=12)
plt.xticks(rotation=0)
plt.yticks(rotation=0)
plt.tight_layout()

plt.show()

# %% [markdown]
# ### Observation
#
# - `TotalCharges` has a strong positive correlation with `tenure`, indicating that customers who stay longer accumulate higher total charges.
# - `MonthlyCharges` has a weak correlation with both `tenure` and `TotalCharges`, suggesting that monthly pricing alone does not explain customer retention.
# - No strong multicollinearity is observed among the numerical features, indicating that each variable provides unique information for further analysis.

# %% [markdown]
# # Business Insights
#
# ## High-Level Insights Summary
#
# | Category | Variable | Key Finding | Impact Level |
# | :--- | :--- | :--- | :--- |
# | **Customer Lifetime** | Tenure | Customers with shorter tenure are significantly more likely to churn. | 🔴 High |
# | **Billing** | Monthly Charges | Customers with higher monthly charges tend to exhibit higher churn rates. | 🟡 Medium |
# | **Customer Value** | Total Charges | Customers with higher total charges are generally long-term subscribers and tend to churn less frequently. | 🟡 Medium |
# | **Demographics** | Gender | Churn rates are nearly identical across genders. | ⚪ Low |
# | **Demographics** | Senior Citizen | Senior citizens show a moderately higher churn rate than non-senior customers. | ⚪ Low |
# | **Household** | Partner | Customers with partners are less likely to churn. | ⚪ Low  |
# | **Household** | Dependents | Customers with dependents exhibit substantially lower churn rates. | 🟡 Medium |
# | **Phone Service** | PhoneService | Phone service alone has little influence on customer churn. | ⚪ Low |
# | **Phone Service** | MultipleLines | Customers with multiple phone lines show a slightly higher churn rate. | 🟡 Medium |
# | **Internet Service** | InternetService | Fiber Optic customers experience the highest churn, while customers without internet service have the lowest churn. | 🔴 High |
# | **Value-Added Services** | OnlineSecurity | Customers without online security are considerably more likely to churn. | 🔴 High |
# | **Value-Added Services** | OnlineBackup | Lack of online backup is associated with increased churn. | 🟡 Medium |
# | **Value-Added Services** | DeviceProtection | Device protection contributes to improved customer retention. | 🟡 Medium |
# | **Value-Added Services** | TechSupport | Customers without technical support exhibit substantially higher churn rates. | 🔴 High |
# | **Entertainment Services** | StreamingTV | Streaming TV has a moderate relationship with churn. | 🟡 Medium |
# | **Entertainment Services** | StreamingMovies | Streaming Movies has a moderate relationship with churn. | 🟡 Medium |
# | **Contract** | Contract Type | Month-to-month contracts have the highest churn rate, while long-term contracts retain customers more effectively. | 🔴 High |
# | **Billing** | PaperlessBilling | Customers using paperless billing tend to churn more frequently. | 🟡 Medium |
# | **Billing** | PaymentMethod | Customers using Electronic Check exhibit the highest churn rate among payment methods. | 🔴 High |
#
# ---
#
# ## Key Business Insights
#
# ### Customer Retention
#
# - Customer tenure is one of the strongest indicators of churn. Customers in the early stages of their subscription are considerably more likely to leave the company.
# - Higher monthly charges are associated with an increased likelihood of churn, suggesting that pricing may influence customer retention.
# - Customers with higher total charges generally remain with the company longer, reflecting greater customer loyalty and lifetime value.
#
# ### Customer Profile
#
# - Gender has little influence on customer churn.
# - Senior citizens show a moderately higher churn tendency than younger customers.
# - Customers with partners and dependents are generally more loyal and less likely to leave the company.
#
# ### Service Performance
#
# - Fiber Optic customers represent the highest-risk customer segment for churn and may require improvements in pricing, service quality, or customer support.
# - Contract type is one of the strongest business drivers of churn. Customers on month-to-month contracts are substantially more likely to leave than those with one-year or two-year contracts.
#
# ### Value-Added Services
#
# - Customers without Online Security and Tech Support experience significantly higher churn rates.
# - Online Backup and Device Protection also contribute to improved customer retention by increasing customer engagement with the company's services.
#
# ### Billing & Payment Behavior
#
# - Customers using Electronic Check have the highest churn rate among payment methods.
# - Paperless Billing is associated with slightly higher churn, suggesting that this customer segment may benefit from targeted retention strategies.
#
# ---
#
# ## Business Recommendations
#
# 1. Prioritize retention campaigns for new customers during their first months of service.
# 2. Review pricing strategies and customer experience for Fiber Optic subscribers.
# 3. Encourage long-term contracts through discounts and loyalty incentives.
# 4. Promote bundled services that include Online Security, Tech Support, and Device Protection.
# 5. Offer personalized incentives to customers with high monthly charges who are identified as being at risk of churn.
# 6. Develop targeted retention campaigns for customers using Electronic Check and month-to-month contracts.
# 7. Leverage churn prediction models to proactively identify high-risk customers and intervene before cancellation.
